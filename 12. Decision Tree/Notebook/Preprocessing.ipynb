# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('titanic/train.csv')
test = pd.read_csv('titanic/test.csv')
submission = pd.read_csv('titanic/gender_submission.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
submission['Survived'] = 1

# %%
submission.to_csv('all_survived.csv', index = False)

# %%
submission['Survived'] = 0

# %%
submission.to_csv('not_survived.csv', index = False)

# %%
train.shape, test.shape
# Out:
# ((891, 12), (418, 11))

# %%
train.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test.isna().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
train.groupby('Pclass')['Cabin'].value_counts(dropna = False).reset_index(name='counts').to_csv('PClass_Cabin_counts.csv', index = False)

# %%
train.Cabin.value_counts()
# Out:
# Cabin
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %%
train.drop_duplicates()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
train['Cabin_Class'] = train['Cabin'].str[0]

# %%
PClass_CabinClas = train.groupby('Pclass')['Cabin_Class'].value_counts(dropna = False).reset_index(name='counts')

# %%
PClass_CabinClas.sort_values(by = ['Pclass','Cabin_Class'])
# Out:
#     Pclass Cabin_Class  counts
# 5        1           A      15
# 1        1           B      47
# 0        1           C      59
# 3        1           D      29
# 4        1           E      25
# 6        1           T       1
# 2        1         NaN      40
# 9        2           D       4
# 10       2           E       4
# 8        2           F       8
# 7        2         NaN     168
# 14       3           E       3
# 12       3           F       5
# 13       3           G       4
# 11       3         NaN     479

# %%
train['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
train['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
train.groupby(['Sex','Parch'])['Age'].median()
# Out:
# Sex     Parch
# female  0        29.0
#         1        26.0
#         2        18.0
#         3        36.0
#         4        37.0
#         5        39.0
#         6        43.0
# male    0        30.0
#         1        19.0
#         2        10.5
#         3        16.0
#         4        52.0
#         5        39.0
# Name: Age, dtype: float64

# %%
train[((train['Sex']=='female') & (train['Parch']==5))]
# Out:
#      PassengerId  Survived  Pclass  \
# 25            26         1       3
# 610          611         0       3
# 638          639         0       3
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 610  Andersson, Mrs. Anders Johan (Alfrida Konstant...  female  39.0      1
# 638             Panula, Mrs. Juha (Maria Emilia Ojala)  female  41.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
#
#      Parch   Ticket     Fare Cabin Embarked Cabin_Class
# 25       5   347077  31.3875   NaN        S         NaN
# 610      5   347082  31.2750   NaN        S         NaN
# 638      5  3101295  39.6875   NaN        S         NaN
# 885      5   382652  29.1250   NaN        Q         NaN

# %%
import pandasql as ps

# %%
# !pip install pandasql
# Out:
# Collecting pandasql
#   Downloading pandasql-0.7.3.tar.gz (26 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.11/site-packages (from pandasql) (1.26.4)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.11/site-packages (from pandasql) (2.1.4)
# Requirement already satisfied: sqlalchemy in /opt/anaconda3/lib/python3.11/site-packages (from pandasql) (2.0.25)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas->pandasql) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas->pandasql) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas->pandasql) (2023.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from sqlalchemy->pandasql) (4.12.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->pandasql) (1.16.0)
# Building wheels for collected packages: pandasql
#   Building wheel for pandasql (setup.py) ... done
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26771 sha256=4e27fb9b23108eab8e1bfa207193e7e3150dcd8a49b1c491431f83954886c4f9
#   Stored in directory: /Users/m.alaudeen/Library/Caches/pip/wheels/68/5d/a5/edc271b998f909801d7956959f699b976cc9896075dc47c153
# Successfully built pandasql
# Installing collected packages: pandasql
# Successfully installed pandasql-0.7.3

# %%
# SQL query using pandasql
query = '''
        SELECT Sex FROM train WHERE Age > 30
        '''
# Execute SQL query on the DataFrame
result = ps.sqldf(query)

# %%
result
# Out:
#         Sex
# 0    female
# 1    female
# 2      male
# 3      male
# 4    female
# ..      ...
# 300    male
# 301  female
# 302    male
# 303  female
# 304    male
#
# [305 rows x 1 columns]

# %%
# SQL query using pandasql
query = '''
        SELECT Pclass, 
       COALESCE(Cabin_Class, 'Unknown') AS Cabin_Class, 
       COUNT(*) AS count
FROM train
GROUP BY Pclass, COALESCE(Cabin_Class, 'Unknown')
ORDER BY Pclass, Cabin_Class;
        '''
# Execute SQL query on the DataFrame
result = ps.sqldf(query)

result
# Out:
#     Pclass Cabin_Class  count
# 0        1           A     15
# 1        1           B     47
# 2        1           C     59
# 3        1           D     29
# 4        1           E     25
# 5        1           T      1
# 6        1     Unknown     40
# 7        2           D      4
# 8        2           E      4
# 9        2           F      8
# 10       2     Unknown    168
# 11       3           E      3
# 12       3           F      5
# 13       3           G      4
# 14       3     Unknown    479

# %%
train['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
train['Name'].str.split(',')
# Out:
# 0                             [Braund,  Mr. Owen Harris]
# 1      [Cumings,  Mrs. John Bradley (Florence Briggs ...
# 2                              [Heikkinen,  Miss. Laina]
# 3        [Futrelle,  Mrs. Jacques Heath (Lily May Peel)]
# 4                            [Allen,  Mr. William Henry]
#                              ...
# 886                             [Montvila,  Rev. Juozas]
# 887                      [Graham,  Miss. Margaret Edith]
# 888          [Johnston,  Miss. Catherine Helen "Carrie"]
# 889                             [Behr,  Mr. Karl Howell]
# 890                               [Dooley,  Mr. Patrick]
# Name: Name, Length: 891, dtype: object

# %%
train['Title'] = train['Name'].apply(lambda x : x.split(',')[1].split('.')[0])

# %%
train.groupby(['Title'])['Age'].median()
# Out:
# Title
#  Capt            70.0
#  Col             58.0
#  Don             40.0
#  Dr              46.5
#  Jonkheer        38.0
#  Lady            48.0
#  Major           48.5
#  Master           3.5
#  Miss            21.0
#  Mlle            24.0
#  Mme             24.0
#  Mr              30.0
#  Mrs             35.0
#  Ms              28.0
#  Rev             46.5
#  Sir             49.0
#  the Countess    33.0
# Name: Age, dtype: float64

# %%
train[['Ticket', 'Pclass']]
# Out:
#                Ticket  Pclass
# 0           A/5 21171       3
# 1            PC 17599       1
# 2    STON/O2. 3101282       3
# 3              113803       1
# 4              373450       3
# ..                ...     ...
# 886            211536       2
# 887            112053       1
# 888        W./C. 6607       3
# 889            111369       1
# 890            370376       3
#
# [891 rows x 2 columns]

# %% [markdown]
# ### Summaries:
# 1. Title Extraction from Name
# 2. Cabin Class Extraction from Cabin Number
# 3. Age imputation based on Title
# 4. Imputation of Cabin Class with respect to the Pclass

# %% [markdown]
# # PURELY FOR HACKATHON PURPOSE

# %%
train = pd.read_csv('titanic/train.csv')
test = pd.read_csv('titanic/test.csv')
submission = pd.read_csv('titanic/gender_submission.csv')

# %%
data = pd.concat([train, test])

# %%
train.shape, test.shape
# Out:
# ((891, 12), (418, 11))

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 413                                 Spector, Mr. Woolf    male   NaN      0
# 414                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 416                                Ware, Mr. Frederick    male   NaN      0
# 417                           Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked
# 0        0           A/5 21171    7.2500   NaN        S
# 1        0            PC 17599   71.2833   C85        C
# 2        0    STON/O2. 3101282    7.9250   NaN        S
# 3        0              113803   53.1000  C123        S
# 4        0              373450    8.0500   NaN        S
# ..     ...                 ...       ...   ...      ...
# 413      0           A.5. 3236    8.0500   NaN        S
# 414      0            PC 17758  108.9000  C105        C
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416      0              359309    8.0500   NaN        S
# 417      1                2668   22.3583   NaN        C
#
# [1309 rows x 12 columns]

# %%
891+418
# Out:
# 1309

# %%
data['source'] = np.where(data['Survived'].isna(),'test','train')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 413                                 Spector, Mr. Woolf    male   NaN      0
# 414                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 416                                Ware, Mr. Frederick    male   NaN      0
# 417                           Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked source
# 0        0           A/5 21171    7.2500   NaN        S  train
# 1        0            PC 17599   71.2833   C85        C  train
# 2        0    STON/O2. 3101282    7.9250   NaN        S  train
# 3        0              113803   53.1000  C123        S  train
# 4        0              373450    8.0500   NaN        S  train
# ..     ...                 ...       ...   ...      ...    ...
# 413      0           A.5. 3236    8.0500   NaN        S   test
# 414      0            PC 17758  108.9000  C105        C   test
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S   test
# 416      0              359309    8.0500   NaN        S   test
# 417      1                2668   22.3583   NaN        C   test
#
# [1309 rows x 13 columns]

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ### 1. Title Extraction

# %%
data.apply(lambda x: len(x), axis = 1)
#(or)
data.apply(len(), axis = 1)

#apply can be used with rows(axis = 0) or columns(axis = 1)
#apply with lambda
#apply without lambda (customized function, built in function)
# Out:
# 0      13
# 1      13
# 2      13
# 3      13
# 4      13
#        ..
# 413    13
# 414    13
# 415    13
# 416    13
# 417    13
# Length: 1309, dtype: int64

# %%
data['Title'] = data['Name'].apply(lambda x : x.split(',')[1].split('.')[0])

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 413                                 Spector, Mr. Woolf    male   NaN      0
# 414                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 416                                Ware, Mr. Frederick    male   NaN      0
# 417                           Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked source    Title
# 0        0           A/5 21171    7.2500   NaN        S  train       Mr
# 1        0            PC 17599   71.2833   C85        C  train      Mrs
# 2        0    STON/O2. 3101282    7.9250   NaN        S  train     Miss
# 3        0              113803   53.1000  C123        S  train      Mrs
# 4        0              373450    8.0500   NaN        S  train       Mr
# ..     ...                 ...       ...   ...      ...    ...      ...
# 413      0           A.5. 3236    8.0500   NaN        S   test       Mr
# 414      0            PC 17758  108.9000  C105        C   test     Dona
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S   test       Mr
# 416      0              359309    8.0500   NaN        S   test       Mr
# 417      1                2668   22.3583   NaN        C   test   Master
#
# [1309 rows x 14 columns]

# %%
data['Cabin_Class'] = data['Cabin'].str[0]

# %%
data['Cabin_Class'].isna().sum()
# Out:
# 1014

# %%
data['Cabin_Class'].fillna('N', inplace = True)

# %%
data.groupby(['Title'])['Age'].mean()
# Out:
# Title
#  Capt            70.000000
#  Col             54.000000
#  Don             40.000000
#  Dona            39.000000
#  Dr              43.571429
#  Jonkheer        38.000000
#  Lady            48.000000
#  Major           48.500000
#  Master           5.482642
#  Miss            21.774238
#  Mlle            24.000000
#  Mme             24.000000
#  Mr              32.252151
#  Mrs             36.994118
#  Ms              28.000000
#  Rev             41.250000
#  Sir             49.000000
#  the Countess    33.000000
# Name: Age, dtype: float64

# %%
data.groupby(['Title'])['Age'].median().reset_index(name='mean').sort_values(by='mean')
# Out:
#             Title  mean
# 8          Master   4.0
# 9            Miss  22.0
# 11            Mme  24.0
# 10           Mlle  24.0
# 14             Ms  28.0
# 12             Mr  29.0
# 17   the Countess  33.0
# 13            Mrs  35.5
# 5        Jonkheer  38.0
# 3            Dona  39.0
# 2             Don  40.0
# 15            Rev  41.5
# 6            Lady  48.0
# 7           Major  48.5
# 16            Sir  49.0
# 4              Dr  49.0
# 1             Col  54.5
# 0            Capt  70.0

# %%
data['Age'] = data.groupby('Title')['Age'].transform(lambda x : x.fillna(x.median()))

# %%
data['Age'] = data.groupby('Title')['Age'].transform(lambda x : x.fillna(x.median()))

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 413                                 Spector, Mr. Woolf    male  29.0      0
# 414                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 416                                Ware, Mr. Frederick    male  29.0      0
# 417                           Peter, Master. Michael J    male   4.0      1
#
#      Parch              Ticket      Fare Cabin Embarked source    Title  \
# 0        0           A/5 21171    7.2500   NaN        S  train       Mr
# 1        0            PC 17599   71.2833   C85        C  train      Mrs
# 2        0    STON/O2. 3101282    7.9250   NaN        S  train     Miss
# 3        0              113803   53.1000  C123        S  train      Mrs
# 4        0              373450    8.0500   NaN        S  train       Mr
# ..     ...                 ...       ...   ...      ...    ...      ...
# 413      0           A.5. 3236    8.0500   NaN        S   test       Mr
# 414      0            PC 17758  108.9000  C105        C   test     Dona
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S   test       Mr
# 416      0              359309    8.0500   NaN        S   test       Mr
# 417      1                2668   22.3583   NaN        C   test   Master
#
#     Cabin_Class
# 0             N
# 1             C
# 2             N
# 3             C
# 4             N
# ..          ...
# 413           N
# 414           C
# 415           N
# 416           N
# 417           N
#
# [1309 rows x 15 columns]

# %%
data.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# source            0
# Title             0
# Cabin_Class       0
# dtype: int64

# %%
data.groupby(['Pclass','Cabin_Class'])['Fare'].median()
# Out:
# Pclass  Cabin_Class
# 1       A              35.07710
#         B              82.26670
#         C              86.28960
#         D              53.10000
#         E              55.44170
#         N              39.60000
#         T              35.50000
# 2       D              13.39585
#         E              11.42500
#         F              26.00000
#         N              15.66460
# 3       E              12.47500
#         F               7.65000
#         G              16.70000
#         N               8.05000
# Name: Fare, dtype: float64

# %%
data[data['Fare'].isna()]
# Out:
#      PassengerId  Survived  Pclass                Name   Sex   Age  SibSp  \
# 152         1044       NaN       3  Storey, Mr. Thomas  male  60.5      0
#
#      Parch Ticket  Fare Cabin Embarked source Title Cabin_Class
# 152      0   3701   NaN   NaN        S   test    Mr           N

# %%
data['Fare'] = data.groupby(['Pclass','Cabin_Class'])['Fare'].transform(lambda x : x.fillna(x.median()))

# %%
data[data.index==152]
# Out:
#      PassengerId  Survived  Pclass                Name   Sex   Age  SibSp  \
# 152          153       0.0       3    Meo, Mr. Alfonzo  male  55.5      0
# 152         1044       NaN       3  Storey, Mr. Thomas  male  60.5      0
#
#      Parch      Ticket  Fare Cabin Embarked source Title Cabin_Class
# 152      0  A.5. 11206  8.05   NaN        S  train    Mr           N
# 152      0        3701  8.05   NaN        S   test    Mr           N

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 413                                 Spector, Mr. Woolf    male  29.0      0
# 414                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 416                                Ware, Mr. Frederick    male  29.0      0
# 417                           Peter, Master. Michael J    male   4.0      1
#
#      Parch              Ticket      Fare Cabin Embarked source    Title  \
# 0        0           A/5 21171    7.2500   NaN        S  train       Mr
# 1        0            PC 17599   71.2833   C85        C  train      Mrs
# 2        0    STON/O2. 3101282    7.9250   NaN        S  train     Miss
# 3        0              113803   53.1000  C123        S  train      Mrs
# 4        0              373450    8.0500   NaN        S  train       Mr
# ..     ...                 ...       ...   ...      ...    ...      ...
# 413      0           A.5. 3236    8.0500   NaN        S   test       Mr
# 414      0            PC 17758  108.9000  C105        C   test     Dona
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S   test       Mr
# 416      0              359309    8.0500   NaN        S   test       Mr
# 417      1                2668   22.3583   NaN        C   test   Master
#
#     Cabin_Class
# 0             N
# 1             C
# 2             N
# 3             C
# 4             N
# ..          ...
# 413           N
# 414           C
# 415           N
# 416           N
# 417           N
#
# [1309 rows x 15 columns]

# %%
data.isna().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          2
# source            0
# Title             0
# Cabin_Class       0
# dtype: int64

# %%
data.groupby(['Embarked'])['Survived'].mean()
# Out:
# Embarked
# C    0.553571
# Q    0.389610
# S    0.339009
# Name: Survived, dtype: float64

# %%
data['Embarked'].mode()[0]
# Out:
# 'S'

# %%
data['Embarked'].fillna(data['Embarked'].mode()[0], inplace = True)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       1.0       1
# 2              3       1.0       3
# 3              4       1.0       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 413         1305       NaN       3
# 414         1306       NaN       1
# 415         1307       NaN       3
# 416         1308       NaN       3
# 417         1309       NaN       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 413                                 Spector, Mr. Woolf    male  29.0      0
# 414                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 416                                Ware, Mr. Frederick    male  29.0      0
# 417                           Peter, Master. Michael J    male   4.0      1
#
#      Parch              Ticket      Fare Cabin Embarked source    Title  \
# 0        0           A/5 21171    7.2500   NaN        S  train       Mr
# 1        0            PC 17599   71.2833   C85        C  train      Mrs
# 2        0    STON/O2. 3101282    7.9250   NaN        S  train     Miss
# 3        0              113803   53.1000  C123        S  train      Mrs
# 4        0              373450    8.0500   NaN        S  train       Mr
# ..     ...                 ...       ...   ...      ...    ...      ...
# 413      0           A.5. 3236    8.0500   NaN        S   test       Mr
# 414      0            PC 17758  108.9000  C105        C   test     Dona
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S   test       Mr
# 416      0              359309    8.0500   NaN        S   test       Mr
# 417      1                2668   22.3583   NaN        C   test   Master
#
#     Cabin_Class
# 0             N
# 1             C
# 2             N
# 3             C
# 4             N
# ..          ...
# 413           N
# 414           C
# 415           N
# 416           N
# 417           N
#
# [1309 rows x 15 columns]

# %%
data_ = data.drop(columns = ['Name','Ticket','Cabin'])

# %%
train_processed = data_[data_['source']=='train']

# %%
test_processed = data_[data_['source']=='test']

# %%
del train_processed['source']

# %%
del test_processed['source']

# %%
train_processed.to_csv('train_processed.csv', index = False)
test_processed.to_csv('test_processed.csv', index = False)
