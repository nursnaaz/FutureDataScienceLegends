# %%
# !unzip data-for-datavis.zip
# Out:
# Archive:  data-for-datavis.zip
#   inflating: cancer_b.csv
#   inflating: candy.csv
#   inflating: iris_virginica.csv
#   inflating: insurance.csv
#   inflating: museum_visitors.csv
#   inflating: fifa.csv
#   inflating: flight_delays.csv
#   inflating: iris.csv
#   inflating: ign_scores.csv
#   inflating: iris_versicolor.csv
#   inflating: iris_setosa.csv
#   inflating: spotify.csv
#   inflating: cancer_m.csv

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Seaborn - Built on top of Matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
fifa = pd.read_csv("fifa.csv")

# %%
fifa
# Out:
#            Date   ARG  BRA   ESP   FRA  GER   ITA
# 0    1993-08-08   5.0  8.0  13.0  12.0  1.0   2.0
# 1    1993-09-23  12.0  1.0  14.0   7.0  5.0   2.0
# 2    1993-10-22   9.0  1.0   7.0  14.0  4.0   3.0
# 3    1993-11-19   9.0  4.0   7.0  15.0  3.0   1.0
# 4    1993-12-23   8.0  3.0   5.0  15.0  1.0   2.0
# ..          ...   ...  ...   ...   ...  ...   ...
# 281  2018-02-15   4.0  2.0   6.0   9.0  1.0  14.0
# 282  2018-03-15   4.0  2.0   6.0   9.0  1.0  14.0
# 283  2018-04-12   5.0  2.0   8.0   7.0  1.0  20.0
# 284  2018-05-17   5.0  2.0   8.0   7.0  1.0  20.0
# 285  2018-06-07   5.0  2.0  10.0   7.0  1.0  19.0
#
# [286 rows x 7 columns]

# %%
fifa['Date']
# Out:
# 0      1993-08-08
# 1      1993-09-23
# 2      1993-10-22
# 3      1993-11-19
# 4      1993-12-23
#           ...
# 281    2018-02-15
# 282    2018-03-15
# 283    2018-04-12
# 284    2018-05-17
# 285    2018-06-07
# Name: Date, Length: 286, dtype: object

# %%
fifa['Date'].astype("datetime64[ns]")
# Out:
# 0     1993-08-08
# 1     1993-09-23
# 2     1993-10-22
# 3     1993-11-19
# 4     1993-12-23
#          ...
# 281   2018-02-15
# 282   2018-03-15
# 283   2018-04-12
# 284   2018-05-17
# 285   2018-06-07
# Name: Date, Length: 286, dtype: datetime64[ns]

# %%
fifa['Date'].astype("datetime64[ns]").dt.day_name()
# Out:
# 0        Sunday
# 1      Thursday
# 2        Friday
# 3        Friday
# 4      Thursday
#          ...
# 281    Thursday
# 282    Thursday
# 283    Thursday
# 284    Thursday
# 285    Thursday
# Name: Date, Length: 286, dtype: object

# %%
fifa = pd.read_csv("fifa.csv",index_col = "Date",parse_dates = True)

# %%
fifa.head()
# Out:
#              ARG  BRA   ESP   FRA  GER  ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0  1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0  2.0

# %%
sns.lineplot(data = fifa)
# Out:
# <Axes: xlabel='Date'>

# %%
plt.figure(figsize = (16,6))
sns.lineplot(data = fifa)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Steps
# ### 1. Load Data
# ### 2. Examine - EDA
# ### 3. Pre-process
# ### 4. Build a Model

# %%
spotify = pd.read_csv("spotify.csv")

# %%
spotify.isna().sum()
# Out:
# Date                         0
# Shape of You                 0
# Despacito                    7
# Something Just Like This    47
# HUMBLE.                     84
# Unforgettable               91
# dtype: int64

# %%
spotify.head()
# Out:
#          Date  Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# 0  2017-01-06      12287078        NaN                       NaN      NaN
# 1  2017-01-07      13190270        NaN                       NaN      NaN
# 2  2017-01-08      13099919        NaN                       NaN      NaN
# 3  2017-01-09      14506351        NaN                       NaN      NaN
# 4  2017-01-10      14275628        NaN                       NaN      NaN
#
#    Unforgettable
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
spotify.tail()
# Out:
#            Date  Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# 361  2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 362  2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 363  2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 364  2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 365  2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#      Unforgettable
# 361      2869783.0
# 362      2743748.0
# 363      2441045.0
# 364      2622693.0
# 365      2627334.0

# %%
spotify = pd.read_csv("spotify.csv",index_col = 'Date', parse_dates = True)

# %%
spotify
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN        NaN
# 2017-01-07      13190270        NaN                       NaN        NaN
# 2017-01-08      13099919        NaN                       NaN        NaN
# 2017-01-09      14506351        NaN                       NaN        NaN
# 2017-01-10      14275628        NaN                       NaN        NaN
# ...                  ...        ...                       ...        ...
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# ...

# %%
sns.lineplot(data = spotify)
# Out:
# <Axes: xlabel='Date'>

# %%
plt.figure(figsize = (16,6))
sns.lineplot(data = spotify)
plt.title("Popular song streams in Spotify from 2017 - 2018")
plt.xlabel("Dates from 2017 - 2018")
plt.ylabel("Streams")
# Out:
# Text(0, 0.5, 'Streams')

# %%
plt.figure(figsize = (16,6))
sns.lineplot(data = spotify['Shape of You'])
sns.lineplot(data = spotify['Despacito'])
#sns.lineplot(data = spotify)
plt.title("Popular song streams in Spotify from 2017 - 2018")
plt.xlabel("Dates from 2017 - 2018")
plt.ylabel("Streams")
# Out:
# Text(0, 0.5, 'Streams')

# %%
plt.figure(figsize = (16,6))
sns.lineplot(data = spotify['Shape of You'])
#sns.lineplot(data = spotify['Despacito'])
#sns.lineplot(data = spotify)
plt.title("Popular song streams in Spotify from 2017 - 2018")
plt.xlabel("Dates from 2017 - 2018")
plt.ylabel("Streams")

plt.figure(figsize = (16,6))
sns.lineplot(data = spotify['Despacito'])
#sns.lineplot(data = spotify)
plt.title("Popular song streams in Spotify from 2017 - 2018")
plt.xlabel("Dates from 2017 - 2018")
plt.ylabel("Streams")
# Out:
# Text(0, 0.5, 'Streams')

# %%
plt.figure(figsize = (16,6))
plt.show()

# %%
flightDelay = pd.read_csv("flight_delays.csv",index_col = 'Month')

# %%
flightDelay.head()
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
#
#              HA         MQ         NK         OO        UA        US  \
# Month
# 1      3.512640  18.164974  11.398054  10.889894  6.352729  3.107457
# 2      6.029967  21.301627  16.474466   9.588895  7.260662  7.114455
# 3      3.468383  11.018418  10.039118   3.181693  4.892212  3.330787
# 4      0.011022   5.131228   8.766224   3.223796  4.376092  2.660290
# 5      0.826426   5.466790  22.397347   4.141162  6.827695  0.681605
#
#              VX        WN
# Month
# 1      1.420702  3.389466
# 2      7.784410  3.501363
# 3      5.348207  3.263341
# ...

# %%
plt.figure(figsize = (16,6))
sns.set(color_codes = False)
sns.barplot(x = flightDelay.index, y = flightDelay['AA'])
# Out:
# <Axes: xlabel='Month', ylabel='AA'>

# %%
plt.figure(figsize = (16,6))
sns.barplot(x = flightDelay.index, y = flightDelay['NK'])
# Out:
# <Axes: xlabel='Month', ylabel='NK'>

# %%
spotify.shape
# Out:
# (366, 5)

# %%
spotify.isna().sum()
# Out:
# Shape of You                 0
# Despacito                    7
# Something Just Like This    47
# HUMBLE.                     84
# Unforgettable               91
# dtype: int64

# %%
sns.set(style = 'darkgrid')
NA = (spotify.isna().sum() / len(spotify))*100
NA = pd.DataFrame(NA, columns = ['count'])
NA.index.names = ['Name']
sns.barplot(x = 'Name', y= 'count', data = NA)

plt.xticks(rotation = 90)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Shape of You'),
#   Text(1, 0, 'Despacito'),
#   Text(2, 0, 'Something Just Like This'),
#   Text(3, 0, 'HUMBLE.'),
#   Text(4, 0, 'Unforgettable')])

# %%
sns.set(style = 'whitegrid')
NA = (spotify.isna().sum() / len(spotify))*100
NA = pd.DataFrame(NA, columns = ['Percentage % of missing values'])
NA.index.names = ['Name']
sns.barplot(x = 'Name', y= 'Percentage % of missing values', data = NA)

plt.xticks(rotation = 90)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Shape of You'),
#   Text(1, 0, 'Despacito'),
#   Text(2, 0, 'Something Just Like This'),
#   Text(3, 0, 'HUMBLE.'),
#   Text(4, 0, 'Unforgettable')])

# %%
#Plot delays of NK..!
#Spotify - Plot percentage of missing values along Y - Column names along X

# %%
NA.reset_index()
# Out:
#                        Name  Percentage % of missing values
# 0              Shape of You                        0.000000
# 1                 Despacito                        1.912568
# 2  Something Just Like This                       12.841530
# 3                   HUMBLE.                       22.950820
# 4             Unforgettable                       24.863388

# %%
sns.set(style = 'whitegrid')
NA = (spotify.isna().sum() / len(spotify))*100
NA = pd.DataFrame(NA, columns = ['Percentage % of missing values'])
NA.index.names = ['Name']
NA.reset_index(inplace = True)
sns.barplot(x = NA['Name'], y= NA['Percentage % of missing values'])

plt.xticks(rotation = 90)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Shape of You'),
#   Text(1, 0, 'Despacito'),
#   Text(2, 0, 'Something Just Like This'),
#   Text(3, 0, 'HUMBLE.'),
#   Text(4, 0, 'Unforgettable')])

# %%
NA
# Out:
#                        Name  Percentage % of missing values
# 0              Shape of You                        0.000000
# 1                 Despacito                        1.912568
# 2  Something Just Like This                       12.841530
# 3                   HUMBLE.                       22.950820
# 4             Unforgettable                       24.863388

# %%
sns.set(style = 'whitegrid')
NA = (spotify.isna().sum() / len(spotify))*100
NA = pd.DataFrame(NA, columns = ['Percentage % of missing values'])
NA.index.names = ['Name']
#NA.reset_index(inplace = True)
sns.barplot(x = NA.index, y= NA['Percentage % of missing values'])

plt.xticks(rotation = 90)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Shape of You'),
#   Text(1, 0, 'Despacito'),
#   Text(2, 0, 'Something Just Like This'),
#   Text(3, 0, 'HUMBLE.'),
#   Text(4, 0, 'Unforgettable')])

# %%
sns.set(style = 'whitegrid')
sns.set_palette("pastel")
NA = (spotify.isna().sum() / len(spotify))*100
NA = pd.DataFrame(NA, columns = ['Percentage % of missing values'])
NA.index.names = ['Name']
#NA.reset_index(inplace = True)
sns.barplot(x = "Name", y= 'Percentage % of missing values', data = NA)

plt.xticks(rotation = 90)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Shape of You'),
#   Text(1, 0, 'Despacito'),
#   Text(2, 0, 'Something Just Like This'),
#   Text(3, 0, 'HUMBLE.'),
#   Text(4, 0, 'Unforgettable')])

# %%
sns.set(style = 'whitegrid')
#sns.set_palette("pastel")
NA = (spotify.isna().sum() / len(spotify))*100
NA = pd.DataFrame(NA, columns = ['Percentage % of missing values'])
NA.index.names = ['Name']
#NA.reset_index(inplace = True)
sns.barplot(x = "Name", y= 'Percentage % of missing values', data = NA, palette = 'deep')

plt.xticks(rotation = 90)
# Out:
# <ipython-input-44-5cf07b03479d>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = "Name", y= 'Percentage % of missing values', data = NA, palette = 'deep')
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Shape of You'),
#   Text(1, 0, 'Despacito'),
#   Text(2, 0, 'Something Just Like This'),
#   Text(3, 0, 'HUMBLE.'),
#   Text(4, 0, 'Unforgettable')])

# %%
sns.set(style = 'whitegrid')
#sns.set_palette("pastel")
colors = ['red', 'blue', 'green', 'purple']
NA = (spotify.isna().sum() / len(spotify))*100
NA = pd.DataFrame(NA, columns = ['Percentage % of missing values'])
NA.index.names = ['Name']
#NA.reset_index(inplace = True)
sns.barplot(x = "Name", y= 'Percentage % of missing values', data = NA, palette = colors)

plt.xticks(rotation = 90)
# Out:
# <ipython-input-45-fa01581deb64>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = "Name", y= 'Percentage % of missing values', data = NA, palette = colors)
# <ipython-input-45-fa01581deb64>:8: UserWarning:
# The palette list has fewer values (4) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x = "Name", y= 'Percentage % of missing values', data = NA, palette = colors)
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Shape of You'),
#   Text(1, 0, 'Despacito'),
#   Text(2, 0, 'Something Just Like This'),
#   Text(3, 0, 'HUMBLE.'),
#   Text(4, 0, 'Unforgettable')])

# %%
sns.set(style = 'whitegrid')
#sns.set_palette("pastel")
#colors = ['red', 'blue', 'green', 'purple']
NA = (spotify.isna().sum() / len(spotify))*100
NA = pd.DataFrame(NA, columns = ['Percentage % of missing values'])
NA.index.names = ['Name']
#NA.reset_index(inplace = True)
barplt = sns.barplot(x = "Name", y= 'Percentage % of missing values', data = NA, palette = 'deep')
for bar in barplt.patches:
  barplt.annotate(format(bar.get_height(),'.2f'),(bar.get_x()+bar.get_width()/2,bar.get_height()),ha = 'center', va = 'center', size = 10, xytext=(0,8), textcoords = "offset points")
plt.xticks(rotation = 90)
# Out:
# <ipython-input-49-7fc5e216aad4>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplt = sns.barplot(x = "Name", y= 'Percentage % of missing values', data = NA, palette = 'deep')
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Shape of You'),
#   Text(1, 0, 'Despacito'),
#   Text(2, 0, 'Something Just Like This'),
#   Text(3, 0, 'HUMBLE.'),
#   Text(4, 0, 'Unforgettable')])

# %%
flightDelay
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
# 6      8.191017 -0.220621   5.047155  4.419594  13.952793  19.712951
# 7      3.870440  0.377408   5.841454  1.204862   6.926421  14.464543
# 8      3.193907  2.503899   9.280950  0.653114   5.154422   9.175737
# 9     -1.432732 -1.813800   3.539154 -3.703377   0.851062   0.978460
# 10    -0.580930 -2.993617   3.676787 -5.011516   2.303760   0.082127
# 11     0.772630 -1.916516   1.418299 -3.175414   4.415930  11.164527
# 12     4.149684 -1.846681  13.839290  2.504595   6.685176   9.346221
#
# ...

# %%
plt.figure(figsize = (10,6))
plt.title("Average Arrival Delyas for each of the flights, by Month")

corr = flightDelay.corr()
sns.heatmap(corr, vmin = -1, vmax = 1, center = 0, annot = True)
# Out:
# <Axes: title={'center': 'Average Arrival Delyas for each of the flights, by Month'}>

# %%
plt.figure(figsize = (10,6))
plt.title("Average Arrival Delyas for each of the flights, by Month")

corr = flightDelay.corr()
sns.heatmap(corr, vmin = -1, vmax = 1, center = 0)
# Out:
# <Axes: title={'center': 'Average Arrival Delyas for each of the flights, by Month'}>

# %%
insurance = pd.read_csv("insurance.csv")

# %%
insurance
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
sns.scatterplot(x = insurance['bmi'], y = insurance['charges'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
sns.scatterplot(x = insurance['bmi'], y = insurance['charges'], hue = insurance['smoker'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
sns.lmplot(x = 'bmi', y = 'charges', hue = 'smoker', data = insurance)

# %%
sns.pairplot(insurance)

# %%
sns.swarmplot(x = insurance['smoker'],y = insurance['charges'], hue = insurance['sex'])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 37.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='smoker', ylabel='charges'>
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 60.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
iris_data = pd.read_csv("iris.csv", index_col = 'Id')

# %%
iris_data
# Out:
#      Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                  5.1               3.5                1.4               0.2
# 2                  4.9               3.0                1.4               0.2
# 3                  4.7               3.2                1.3               0.2
# 4                  4.6               3.1                1.5               0.2
# 5                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 146                6.7               3.0                5.2               2.3
# 147                6.3               2.5                5.0               1.9
# 148                6.5               3.0                5.2               2.0
# 149                6.2               3.4                5.4               2.3
# 150                5.9               3.0                5.1               1.8
#
#             Species
# Id
# ...

# %%
sns.distplot(a = iris_data["Sepal Length (cm)"], kde = False)
# Out:
# <ipython-input-84-56ea5c269133>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a = iris_data["Sepal Length (cm)"], kde = False)
# <Axes: xlabel='Sepal Length (cm)'>

# %%
sns.kdeplot(data = iris_data["Sepal Length (cm)"], shade = True)
# Out:
# <ipython-input-82-bb76a6116944>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data = iris_data["Sepal Length (cm)"], shade = True)
# <Axes: xlabel='Sepal Length (cm)', ylabel='Density'>

# %%
sns.jointplot(x = iris_data["Sepal Length (cm)"], y = iris_data['Petal Length (cm)'], kind = "kde")
